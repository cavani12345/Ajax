# %% [markdown]
# <a href="https://colab.research.google.com/github/cavani12345/Ajax/blob/master/colab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from skimage import io
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
 filepath = '/gdrive/MyDrive/james.jpg'
 io.imshow(filepath)

# %%
import pandas as pd
import numpy as np

filepath= "/gdrive/MyDrive/Iris.csv"
dataset= pd.read_csv(filepath)
dataset.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# columns names
dataset.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')
